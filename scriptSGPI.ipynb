-- %% [markdown]
-- # [Linea_Viva]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Linea_Viva]    Script Date: 25/02/2024 2:14:42 p. m. ******/
CREATE DATABASE [Linea_Viva]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Linea_Viva', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\Linea_Viva.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Linea_Viva_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\Linea_Viva_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Linea_Viva] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Linea_Viva].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Linea_Viva] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Linea_Viva] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Linea_Viva] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Linea_Viva] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Linea_Viva] SET ARITHABORT OFF 
GO
ALTER DATABASE [Linea_Viva] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Linea_Viva] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Linea_Viva] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Linea_Viva] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Linea_Viva] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Linea_Viva] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Linea_Viva] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Linea_Viva] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Linea_Viva] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Linea_Viva] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Linea_Viva] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Linea_Viva] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Linea_Viva] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Linea_Viva] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Linea_Viva] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Linea_Viva] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Linea_Viva] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Linea_Viva] SET RECOVERY FULL 
GO
ALTER DATABASE [Linea_Viva] SET  MULTI_USER 
GO
ALTER DATABASE [Linea_Viva] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Linea_Viva] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Linea_Viva] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Linea_Viva] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Linea_Viva] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Linea_Viva] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Linea_Viva', N'ON'
GO
ALTER DATABASE [Linea_Viva] SET QUERY_STORE = ON
GO
ALTER DATABASE [Linea_Viva] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Inspecciones]

-- %%
USE [Linea_Viva]
GO

-- %%
/****** Object:  Table [dbo].[Inspecciones]    Script Date: 25/02/2024 2:14:44 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Inspecciones](
	[IdInspecciones] [int] NOT NULL,
	[Fecha_inspeccion] [date] NOT NULL,
	[IdInventario] [int] NULL,
 CONSTRAINT [PK_Inspecciones] PRIMARY KEY CLUSTERED 
(
	[IdInspecciones] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Inventario]

-- %%
/****** Object:  Table [dbo].[Inventario]    Script Date: 25/02/2024 2:14:44 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Inventario](
	[IdInventario] [int] NOT NULL,
	[Tipo_Equipo] [varchar](100) NOT NULL,
	[Descripcion] [varchar](100) NOT NULL,
 CONSTRAINT [PK_Inventario] PRIMARY KEY CLUSTERED 
(
	[IdInventario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Inspecciones_Inventario]

-- %%
ALTER TABLE [dbo].[Inspecciones]  WITH CHECK ADD  CONSTRAINT [FK_Inspecciones_Inventario] FOREIGN KEY([IdInventario])
REFERENCES [dbo].[Inventario] ([IdInventario])
GO
ALTER TABLE [dbo].[Inspecciones] CHECK CONSTRAINT [FK_Inspecciones_Inventario]
GO

-- %% [markdown]
-- # [Linea_Viva]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Linea_Viva] SET  READ_WRITE 
GO
